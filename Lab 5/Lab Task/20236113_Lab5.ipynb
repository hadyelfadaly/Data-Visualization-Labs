# %% [markdown]
# ### Haneen Hisham 20236032
# ### Bonus Lab 5 Task

# %%
# install required libraries
# !pip install dash
# !pip install dash-html-components
# !pip install dash-core-components
# !pip install dash_bootstrap_components
# !pip install dash_bootstrap_templates
# !pip install gapminder
# !pip install plotly
# Out:
# Collecting dash
#   Downloading dash-3.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting Flask<3.2,>=1.0.4 (from dash)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.2 (from dash)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting plotly>=5.0.0 (from dash)
#   Downloading plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting importlib-metadata (from dash)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\mobig\myenv\lib\site-packages (from dash) (4.13.2)
# Requirement already satisfied: requests in c:\users\mobig\myenv\lib\site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in c:\users\mobig\myenv\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\mobig\myenv\lib\site-packages (from dash) (78.1.0)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from Flask<3.2,>=1.0.4->dash)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: colorama in c:\users\mobig\myenv\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash) (0.4.6)
# Collecting narwhals>=1.15.1 (from plotly>=5.0.0->dash)
#   Downloading narwhals-2.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\mobig\myenv\lib\site-packages (from plotly>=5.0.0->dash) (24.2)
# Collecting zipp>=3.20 (from importlib-metadata->dash)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mobig\myenv\lib\site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mobig\myenv\lib\site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mobig\myenv\lib\site-packages (from requests->dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mobig\myenv\lib\site-packages (from requests->dash) (2025.1.31)
# Downloading dash-3.3.0-py3-none-any.whl (7.9 MB)
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.9 MB 1.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.9 MB 1.9 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/7.9 MB 1.9 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/7.9 MB 1.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/7.9 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 2.6/7.9 MB 1.9 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/7.9 MB 1.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.4/7.9 MB 1.9 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/7.9 MB 1.8 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/7.9 MB 1.8 MB/s eta 0:00:03
#    --------------------- ------------------ 4.2/7.9 MB 1.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.7/7.9 MB 1.8 MB/s eta 0:00:02
#    ------------------------- -------------- 5.0/7.9 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/7.9 MB 1.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.8/7.9 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 6.0/7.9 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 6.6/7.9 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.9 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.9 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  7.9/7.9 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 1.8 MB/s  0:00:04
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 2.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.9 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.9 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.9 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.9 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.9 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.9 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 3.7/9.9 MB 2.0 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.9 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 4.5/9.9 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/9.9 MB 2.0 MB/s eta 0:00:03
#    --------------------- ------------------ 5.2/9.9 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.8/9.9 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 6.0/9.9 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.9 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.9 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.9 MB 2.0 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/9.9 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/9.9 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 2.0 MB/s  0:00:05
# Downloading narwhals-2.11.0-py3-none-any.whl (423 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, Werkzeug, retrying, narwhals, itsdangerous, click, blinker, plotly, importlib-metadata, Flask, dash
#
#    --- ------------------------------------  1/11 [Werkzeug]
#    ---------- -----------------------------  3/11 [narwhals]
#    ---------- -----------------------------  3/11 [narwhals]
#    ---------- -----------------------------  3/11 [narwhals]
#    ---------- -----------------------------  3/11 [narwhals]
#    ---------- -----------------------------  3/11 [narwhals]
#    -------------- -------------------------  4/11 [itsdangerous]
#    ------------------ ---------------------  5/11 [click]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ------------------------- --------------  7/11 [plotly]
#    ----------------------------- ----------  8/11 [importlib-metadata]
#    ------------------------------------ --- 10/11 [dash]
#    ------------------------------------ --- 10/11 [dash]
#    ------------------------------------ --- 10/11 [dash]
#    ------------------------------------ --- 10/11 [dash]
#    ------------------------------------ --- 10/11 [dash]
#    ------------------------------------ --- 10/11 [dash]
#    ------------------------------------ --- 10/11 [dash]
#    ---------------------------------------- 11/11 [dash]
#
# Successfully installed Flask-3.1.2 Werkzeug-3.1.3 blinker-1.9.0 click-8.3.0 dash-3.3.0 importlib-metadata-8.7.0 itsdangerous-2.2.0 narwhals-2.11.0 plotly-6.4.0 retrying-1.4.2 zipp-3.23.0
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# Collecting dash-html-components
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Installing collected packages: dash-html-components
# Successfully installed dash-html-components-2.0.0
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# Collecting dash-core-components
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: dash-core-components
# Successfully installed dash-core-components-2.0.0
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# Collecting dash_bootstrap_components
#   Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: dash>=3.0.4 in c:\users\mobig\myenv\lib\site-packages (from dash_bootstrap_components) (3.3.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (6.4.0)
# Requirement already satisfied: importlib-metadata in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (4.13.2)
# Requirement already satisfied: requests in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (2.32.3)
# Requirement already satisfied: retrying in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\mobig\myenv\lib\site-packages (from dash>=3.0.4->dash_bootstrap_components) (78.1.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash_bootstrap_components) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash_bootstrap_components) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash_bootstrap_components) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash_bootstrap_components) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash_bootstrap_components) (3.0.2)
# Requirement already satisfied: colorama in c:\users\mobig\myenv\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash>=3.0.4->dash_bootstrap_components) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\mobig\myenv\lib\site-packages (from plotly>=5.0.0->dash>=3.0.4->dash_bootstrap_components) (2.11.0)
# Requirement already satisfied: packaging in c:\users\mobig\myenv\lib\site-packages (from plotly>=5.0.0->dash>=3.0.4->dash_bootstrap_components) (24.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\mobig\myenv\lib\site-packages (from importlib-metadata->dash>=3.0.4->dash_bootstrap_components) (3.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mobig\myenv\lib\site-packages (from requests->dash>=3.0.4->dash_bootstrap_components) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mobig\myenv\lib\site-packages (from requests->dash>=3.0.4->dash_bootstrap_components) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mobig\myenv\lib\site-packages (from requests->dash>=3.0.4->dash_bootstrap_components) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mobig\myenv\lib\site-packages (from requests->dash>=3.0.4->dash_bootstrap_components) (2025.1.31)
# Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl (204 kB)
# Installing collected packages: dash_bootstrap_components
# Successfully installed dash_bootstrap_components-2.0.4
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# Collecting dash_bootstrap_templates
#   Downloading dash_bootstrap_templates-2.1.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: dash in c:\users\mobig\myenv\lib\site-packages (from dash_bootstrap_templates) (3.3.0)
# Requirement already satisfied: dash-bootstrap-components>=1.0.0 in c:\users\mobig\myenv\lib\site-packages (from dash_bootstrap_templates) (2.0.4)
# Requirement already satisfied: numpy in c:\users\mobig\myenv\lib\site-packages (from dash_bootstrap_templates) (2.2.4)
# Requirement already satisfied: plotly<7,>=6 in c:\users\mobig\myenv\lib\site-packages (from dash_bootstrap_templates) (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\mobig\myenv\lib\site-packages (from plotly<7,>=6->dash_bootstrap_templates) (2.11.0)
# Requirement already satisfied: packaging in c:\users\mobig\myenv\lib\site-packages (from plotly<7,>=6->dash_bootstrap_templates) (24.2)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\mobig\myenv\lib\site-packages (from dash->dash_bootstrap_templates) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\mobig\myenv\lib\site-packages (from dash->dash_bootstrap_templates) (3.1.3)
# Requirement already satisfied: importlib-metadata in c:\users\mobig\myenv\lib\site-packages (from dash->dash_bootstrap_templates) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\mobig\myenv\lib\site-packages (from dash->dash_bootstrap_templates) (4.13.2)
# Requirement already satisfied: requests in c:\users\mobig\myenv\lib\site-packages (from dash->dash_bootstrap_templates) (2.32.3)
# Requirement already satisfied: retrying in c:\users\mobig\myenv\lib\site-packages (from dash->dash_bootstrap_templates) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\mobig\myenv\lib\site-packages (from dash->dash_bootstrap_templates) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\mobig\myenv\lib\site-packages (from dash->dash_bootstrap_templates) (78.1.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash->dash_bootstrap_templates) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash->dash_bootstrap_templates) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash->dash_bootstrap_templates) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash->dash_bootstrap_templates) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\mobig\myenv\lib\site-packages (from Flask<3.2,>=1.0.4->dash->dash_bootstrap_templates) (3.0.2)
# Requirement already satisfied: colorama in c:\users\mobig\myenv\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash->dash_bootstrap_templates) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\mobig\myenv\lib\site-packages (from importlib-metadata->dash->dash_bootstrap_templates) (3.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mobig\myenv\lib\site-packages (from requests->dash->dash_bootstrap_templates) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mobig\myenv\lib\site-packages (from requests->dash->dash_bootstrap_templates) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mobig\myenv\lib\site-packages (from requests->dash->dash_bootstrap_templates) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mobig\myenv\lib\site-packages (from requests->dash->dash_bootstrap_templates) (2025.1.31)
# Downloading dash_bootstrap_templates-2.1.0-py3-none-any.whl (100 kB)
# Installing collected packages: dash_bootstrap_templates
# Successfully installed dash_bootstrap_templates-2.1.0
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# Collecting gapminder
#   Downloading gapminder-0.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pandas in c:\users\mobig\myenv\lib\site-packages (from gapminder) (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mobig\myenv\lib\site-packages (from pandas->gapminder) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mobig\myenv\lib\site-packages (from pandas->gapminder) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mobig\myenv\lib\site-packages (from pandas->gapminder) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mobig\myenv\lib\site-packages (from pandas->gapminder) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\mobig\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas->gapminder) (1.17.0)
# Downloading gapminder-0.1-py3-none-any.whl (32 kB)
# Installing collected packages: gapminder
# Successfully installed gapminder-0.1
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# Requirement already satisfied: plotly in c:\users\mobig\myenv\lib\site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\mobig\myenv\lib\site-packages (from plotly) (2.11.0)
# Requirement already satisfied: packaging in c:\users\mobig\myenv\lib\site-packages (from plotly) (24.2)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)

# %%
from dash import Dash, html, dcc, dash_table, Input, Output, callback
import dash_bootstrap_components as dbc
import plotly.express as px
from dash_bootstrap_templates import ThemeChangerAIO, template_from_url


# load dataset once to avoid reloading it on every request
gap = px.data.gapminder()

#store unique years & continents for UI inputs
year_list = sorted(gap["year"].unique())
continent_list = sorted(gap["continent"].unique())


# initialize app with bootstrap + template styles
external_styles = [
    dbc.themes.BOOTSTRAP,
    "https://cdn.jsdelivr.net/gh/AnnMarieW/dash-bootstrap-templates/dbc.min.css",
]
app = Dash(__name__, external_stylesheets=external_styles)

# -------------------------------------------------------
# header of the page
# -------------------------------------------------------
header_section = html.H4(
    "Interactive Gapminder Dashboard",
    className="bg-primary text-center text-white p-2 mb-3",
)


# data table component (used in table tab)
data_table = html.Div(
    dash_table.DataTable(
        id="gap-table",
        columns=[{"name": col, "id": col} for col in gap.columns],  # columns from dataset
        data=gap.to_dict("records"),  # initial table contents
        editable=True,
        filter_action="native",
        sort_action="native",
        page_size=10,
        style_table={"overflowX": "auto"},  # allow horizontal scroll
        row_selectable="multi",
    ),
    className="dbc-row-selectable",
)


# dropdown for y-axis indicator (gdpPercap, lifeExp, pop)
indicator_dropdown = html.Div(
    [
        dbc.Label("Y-Axis Indicator"),
        dcc.Dropdown(
            id="y-indicator",
            options=[{"label": x, "value": x} for x in ["gdpPercap", "lifeExp", "pop"]],
            value="pop",  # default indicator
            clearable=False,
        ),
    ],
    className="mb-3",
)


# checklist of continents (user can toggle which continents appear)
continent_selector = html.Div(
    [
        dbc.Label("Choose Continents"),
        dbc.Checklist(
            id="continent-selection",
            options=[{"label": c, "value": c} for c in continent_list],
            value=continent_list,  # select all by default
            inline=True,
        ),
    ],
    className="mb-3",
)

# year slider with proper marks 
year_slider = html.Div(
    [
        dbc.Label("Year Range"),
        dcc.RangeSlider(
            id="year-slider",
            min=int(year_list[0]),
            max=int(year_list[-1]),
            step=5,
            value=[int(year_list[2]), int(year_list[-2])],

           # only show first and last year so UI is clean
            marks={
                str(year_list[0]): str(year_list[0]),
                str(year_list[-1]): str(year_list[-1]),
            },

            tooltip={"always_visible": True},
        ),
    ],
    className="mb-3",
)



# combine all controls into one card
control_panel = dbc.Card(
    [
        indicator_dropdown,
        continent_selector,
        year_slider,
        ThemeChangerAIO(aio_id="theme"),  # theme switcher
    ],
    body=True,
)


# graph tabs
tab_line = dbc.Tab(dcc.Graph(id="line-plot"), label="Line Chart")
tab_scatter = dbc.Tab(dcc.Graph(id="scatter-plot"), label="Scatter Chart")
tab_table = dbc.Tab(data_table, label="Table", className="p-3")

#wrap all tabs in a card
tab_container = dbc.Card(dbc.Tabs([tab_line, tab_scatter, tab_table]))


# main layout of the app
app.layout = dbc.Container(
    [
        header_section,
        dbc.Row(
            [
                dbc.Col(control_panel, width=4),  # left side controls
                dbc.Col(tab_container, width=8),   # right side output
            ]
        ),
    ],
    fluid=True,
)

# callback: main logic to update line graph, scatter graph, and table
@callback(
    Output("line-plot", "figure"),
    Output("scatter-plot", "figure"),
    Output("gap-table", "data"),
    Input("y-indicator", "value"),
    Input("continent-selection", "value"),
    Input("year-slider", "value"),
    Input(ThemeChangerAIO.ids.radio("theme"), "value"),
)
def update_visuals(y_value, chosen_continents, year_range, theme_selected):

    #empty selection case
    if not chosen_continents:
        return {}, {}, []

    #filter based on user-selected years & continents
    filtered = gap[
        (gap["year"] >= year_range[0])
        & (gap["year"] <= year_range[1])
        & (gap["continent"].isin(chosen_continents))
    ]

    #table needs the filtered data
    table_data = filtered.to_dict("records")

    # line chart
    fig_line = px.line(
        filtered,
        x="year",
        y=y_value,
        color="continent",
        line_group="country",
        template=template_from_url(theme_selected),  # theme applied
    )

    # scatter chart
    latest_year = year_range[1]  # show scatter for latest selected year
    scatter_data = filtered[filtered["year"] == latest_year]

    fig_scat = px.scatter(
        scatter_data,
        x="gdpPercap",
        y="lifeExp",
        size="pop",
        color="continent",
        log_x=True,
        size_max=60,
        template=template_from_url(theme_selected),
        title=f"Gapminder {latest_year} — {theme_selected} Theme",
    )

    return fig_line, fig_scat, table_data

# run server
if __name__ == "__main__":
    
    app.run(debug=False, use_reloader=False, port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
