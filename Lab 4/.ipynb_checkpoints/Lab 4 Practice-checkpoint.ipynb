# %%
import folium
import matplotlib as plt
from branca.element import figure
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import folium
#       2 import matplotlib as plt
# ----> 3 from branca.element import figure
#       4 import seaborn as sns
#
# ImportError: cannot import name 'figure' from 'branca.element' (C:\Users\mobig\myenv\Lib\site-packages\branca\element.py)

# %%
pip install branca.element
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\mobig\myenv\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement branca.element (from versions: none)
# ERROR: No matching distribution found for branca.element
